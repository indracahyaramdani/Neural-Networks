# %% [markdown]
# # Import Library

# %%
import NeuralNetworks as nn 
import numpy as np
from nnfs.datasets import spiral_data

# %% [markdown]
# # Import Dataset

# %%
X, y = spiral_data(samples=100, classes=3)

# %% [markdown]
# # Data Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y)

# %%
X_train=X_train
y_train=y_train.reshape(-1, 1)
X_test=X_test
y_test=y_test.reshape(-1, 1)

# %%
X_train.shape[1]
# Out:
# 2

# %%
X_train
# Out:
# array([[ 2.49640269e-01, -8.15615713e-02],
#        [-2.61899555e-01, -1.89440644e-01],
#        [-6.83702983e-01, -1.80275390e-01],
#        [ 6.50825647e-02, -1.14049981e-01],
#        [-4.83479107e-02,  5.23022652e-01],
#        [-3.23569259e-01, -2.74380336e-01],
#        [ 2.76640823e-01,  8.12797350e-01],
#        [-4.84588741e-01, -1.58683844e-02],
#        [-3.05102931e-02,  2.50675338e-01],
#        [ 9.46467999e-02, -4.96102808e-01],
#        [ 1.28844761e-01,  8.99914056e-01],
#        [ 3.06921720e-01,  5.10849193e-01],
#        [-6.04155700e-04, -1.00829262e-02],
#        [ 6.38413698e-02,  2.65149853e-01],
#        [-3.07842045e-01, -8.55382696e-01],
#        [-8.46842767e-02, -2.80421369e-01],
#        [-6.55576264e-01,  3.37549687e-01],
#        [ 8.92667205e-01, -1.72021922e-01],
#        [-1.36498943e-01, -1.62368245e-01],
#        [-1.17304719e-01,  5.01618068e-01],
#        [ 1.89305558e-01,  2.61997214e-01],
#        [ 2.17029439e-03,  5.45450228e-01],
#        [-2.67696529e-03,  2.42409462e-01],
#        [-8.74647728e-02, -2.04285657e-01],
#        [-4.74731642e-01,  1.40017393e-01],
#        [ 1.82237674e-01, -8.71871094e-02],
#        [ 5.99695651e-01,  1.41492980e-01],
#        [ 1.10693075e-01,  7.06412180e-02],
#        [ 4.14836877e-01,  5.08909448e-01],
#        [ 2.85608398e-01, -6.50800561e-02],
#        [-4.42451919e-01, -4.20376421e-02],
#        [ 3.68626253e-01, -6.15979691e-02],
#        [ 2.07734825e-01, -5.80087390e-01],
#        [-8.10404585e-02,  6.02949798e-02],
#        [-5.49469980e-01, -4.12154503e-01],
#        [-0.00000000e+00, -0.00000000e+00],
#        [-2.28001839e-01, -6.37204559e-01],
#        [ 1.91619508e-01,  6.06828346e-01],
#        [-1.44411134e-01,  4.52250582e-01],
#        [ 1.89601114e-01, -8.99424929e-01],
#        [ 3.24391601e-01, -6.73415613e-01],
#        [-6.67927421e-01,  3.35546508e-01],
#        [-3.62750956e-02, -1.77933673e-02],
#        [ 1.11460093e-01, -1.02632786e-01],
#        [-7.08328055e-01, -3.67482142e-01],
#        [ 7.76164909e-01,  5.64262740e-01],
#        [ 6.86038134e-01,  3.87433430e-01],
#        [-2.64356352e-01,  5.00083062e-01],
#        [ 5.58820558e-01, -4.81081711e-01],
#        [-1.96259736e-01, -3.29869703e-01],
#        [ 2.56767588e-01,  1.18584330e-01],
#        [ 2.73870744e-01,  5.63204841e-01],
#        [-3.82162387e-01, -3.58303631e-02],
#        [ 4.69883362e-01, -1.55514079e-01],
#        [ 4.20885809e-01, -5.32613370e-02],
#        [-7.31299814e-02, -3.43795251e-02],
#        [ 3.93507033e-01,  2.06598836e-01],
#        [-2.51448557e-03, -5.15145378e-01],
#        [-1.22271230e-01,  1.60816381e-01],
#        [ 3.13056234e-02,  5.85021573e-01],
#        [ 5.65156036e-02, -2.18879221e-02],
#        [ 2.57142318e-02,  5.48805327e-02],
#        [-2.81719981e-02, -2.71268324e-01],
#        [-1.97769070e-01,  7.66994355e-02],
#        [-1.14490116e-01,  1.54029184e-01],
#        [-2.48572511e-01,  3.92565974e-01],
#        [ 7.90842824e-02, -2.61009275e-01],
#        [ 3.63349686e-01, -6.99092262e-01],
#        [-6.36389732e-01,  1.13686625e-01],
#        [ 5.94621250e-02,  5.01537903e-01],
#        [ 6.01610758e-02, -1.60833554e-01],
#        [ 0.00000000e+00,  0.00000000e+00],
#        [-4.67383613e-01, -8.38079330e-01],
#        [-4.73913215e-01,  2.81323577e-02],
#        [ 3.20464137e-01, -8.83042304e-01],
#        [ 6.24777928e-01,  2.01819230e-01],
#        [-6.44319528e-03, -1.91469803e-02],
#        [-3.24815346e-01, -2.56920420e-01],
#        [ 7.27751637e-01, -1.70575653e-01],
#        [ 6.82309191e-02,  1.85480868e-02],
#        [-1.23051328e-01,  4.58422204e-02],
#        [ 1.92044454e-01,  8.05711717e-01],
#        [ 2.01862321e-02, -7.98532488e-04],
#        [-6.16817393e-02,  3.99304409e-01],
#        [ 7.36267058e-01,  3.07705341e-01],
#        [-6.36288789e-01, -6.20693188e-01],
#        [-9.05254063e-02, -4.76322584e-01],
#        [-3.68691090e-01,  7.30402881e-01],
#        [-2.83571689e-01, -6.36674058e-01],
#        [ 4.08596467e-01,  5.26776396e-01],
#        [ 8.05335062e-02,  6.65584673e-03],
#        [ 3.05777370e-01,  4.99730410e-01],
#        [ 1.54262439e-01,  8.24069512e-01],
#        [-2.94410647e-01,  8.38716774e-01],
#        [ 3.82000855e-01,  1.31620648e-01]])

# %% [markdown]
# # Build Model

# %%
model = nn.Model()
# Add layers
model.add(nn.Layer_Dense(X_train.shape[1], 3))
model.add(nn.Activation_ReLU())
model.add(nn.Layer_Dense(3, 6))
model.add(nn.Activation_ReLU())
model.add(nn.Layer_Dense(6, 3))
model.add(nn.Activation_Softmax())

# %%
model.set(
loss=nn.Loss_CategoricalCrossentropy(),
optimizer=nn.Optimizer_Adam(decay=1e-3),
accuracy=nn.Accuracy_Categorical()
)

# %%
model.finalize()

# %%
model.train(X_train, y_train, batch_size=128, print_every=100, validation_data=(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# C:\Users\KEPALA~1\AppData\Local\Temp/ipykernel_1832/2896800161.py in <module>
# ----> 1 model.train(X_train, y_train, batch_size=128, print_every=100, validation_data=(X_test, y_test))
#
# c:\Users\Kepala Laboratorium\Documents\GitHub\Neural-Networks\NeuralNetworks.py in train(self, X, y, epochs, batch_size, print_every, validation_data)
#     787
#     788         #Main taining loop
# --> 789         for epoch in range(1, epochs+1):
#     790
#     791             #print epoch number
#
# UnboundLocalError: local variable 'epoch' referenced before assignment

# %% [markdown]
# # Model Evaluate

# %%
model.evaluate(X, y)

# %% [markdown]
# # Model Prediction

# %%
confidences = model.predict(X_test[:5])
