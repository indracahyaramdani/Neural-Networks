# %% [markdown]
# # Import Library

# %%
import NeuralNetworks as nn 
import numpy as np
from nnfs.datasets import spiral_data

# %% [markdown]
# # Import Dataset

# %%
X, y = spiral_data(samples=100, classes=3)

# %% [markdown]
# # Data Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y)

# %%
X_train=X_train
y_train=y_train.reshape(-1, 1)
X_test=X_test
y_test=y_test.reshape(-1, 1)

# %%
X_train.shape[1]
# Out:
# 2

# %%
X_train
# Out:
# array([[ 4.13832726e-01, -6.58544415e-01],
#        [-5.79800080e-01,  6.33246827e-01],
#        [-2.04128945e-01,  4.50895084e-01],
#        [-8.46024059e-01,  6.45742239e-02],
#        [-1.81135733e-01,  4.38833694e-01],
#        [ 3.47399445e-01,  4.96611603e-01],
#        [-1.06484013e-01, -5.76100198e-01],
#        [-1.27947881e-02, -1.71239833e-01],
#        [ 1.20585765e-01,  5.19828014e-02],
#        [-7.75124293e-01, -6.41919166e-02],
#        [ 3.87377208e-01, -8.44703645e-01],
#        [ 2.43039190e-02,  6.86438572e-01],
#        [ 2.34088006e-01,  3.77801098e-01],
#        [ 1.31740096e-01, -1.53155833e-01],
#        [ 1.61046009e-02,  2.56693490e-02],
#        [-3.09431667e-01, -3.60051675e-01],
#        [-5.99231056e-01,  4.29700093e-01],
#        [ 5.32882300e-01,  2.66841328e-01],
#        [ 4.45705387e-01,  4.25443117e-01],
#        [ 1.70213603e-01, -2.26741324e-02],
#        [-1.11635121e-01, -2.59864267e-01],
#        [-5.07940974e-02,  4.61861772e-01],
#        [ 5.79690710e-01, -3.49246574e-01],
#        [ 7.48745176e-01, -1.69435182e-01],
#        [-1.41735898e-01,  4.31882513e-01],
#        [ 1.76394322e-01, -4.40782769e-02],
#        [-4.78528055e-02, -3.19670524e-01],
#        [ 6.65511965e-01,  2.67262225e-01],
#        [-7.59559195e-02,  5.50338690e-01],
#        [-5.25218150e-01,  6.00921545e-03],
#        [-5.19932476e-01, -1.27568133e-01],
#        [-5.42297344e-03, -2.52467017e-01],
#        [ 1.16025485e-01, -9.74419205e-02],
#        [ 2.36308066e-01, -4.00068538e-01],
#        [-9.41778563e-01, -1.20804792e-01],
#        [-7.67675801e-01,  1.21843746e-03],
#        [-1.22861434e-01,  2.54748711e-01],
#        [ 2.46391767e-01,  1.93241601e-01],
#        [-2.01297933e-02, -1.70676339e-03],
#        [-3.91064434e-01, -4.75063642e-02],
#        [ 1.92006583e-01, -1.30795857e-01],
#        [ 2.42495144e-01, -4.88586498e-01],
#        [-1.80657886e-01,  4.71634118e-01],
#        [-4.04240704e-01,  4.91475463e-01],
#        [ 5.20155539e-03,  1.95208976e-02],
#        [ 2.51387514e-03, -1.21186050e-01],
#        [ 6.88623697e-01, -1.60456814e-01],
#        [ 5.76292283e-01, -5.07163509e-01],
#        [-3.41979307e-01,  3.43697843e-01],
#        [ 1.20066873e-01, -1.74869536e-01],
#        [-1.01411310e-01,  1.12572587e-01],
#        [ 7.34241016e-02, -3.37468106e-02],
#        [-8.39159443e-02, -8.13867066e-01],
#        [-6.03096506e-02, -5.98670440e-03],
#        [-5.66416102e-02, -3.79636185e-01],
#        [-3.61210711e-01,  3.38381182e-01],
#        [-5.79884581e-01, -2.62092636e-01],
#        [-1.06925355e-01,  1.94806787e-01],
#        [-8.33843372e-02, -9.45826470e-01],
#        [ 1.09457888e-02,  2.62398063e-01],
#        [ 6.71920501e-01,  7.13110736e-01],
#        [ 5.51857540e-01, -3.36704313e-01],
#        [ 6.08517341e-01, -3.39813778e-01],
#        [-4.53474768e-01, -3.11802085e-02],
#        [ 1.41141066e-01,  8.78401319e-03],
#        [ 3.39293403e-02,  9.51411602e-02],
#        [ 7.74931668e-01, -3.19950574e-01],
#        [ 1.11017412e-01, -4.56215511e-03],
#        [ 1.64333132e-01, -8.83842441e-01],
#        [-2.46203712e-01, -2.81182071e-01],
#        [-6.20590195e-01, -1.81064487e-01],
#        [ 7.83354833e-02, -4.61304115e-02],
#        [ 9.46375897e-02,  6.49709310e-01],
#        [-2.61247829e-01, -9.54803426e-01],
#        [ 4.08230928e-01, -6.97181514e-02],
#        [ 2.83143277e-01,  2.28169431e-01],
#        [ 1.78660035e-01,  3.37408217e-02],
#        [-8.54467988e-02,  7.10248096e-02],
#        [-5.11670437e-01,  4.87998308e-01],
#        [ 4.38120766e-02, -1.55564410e-01],
#        [ 3.96030450e-03,  5.03495394e-02],
#        [ 6.70596975e-02,  5.31136898e-01],
#        [ 1.88994809e-01,  7.33622512e-01],
#        [-8.91077391e-01, -3.82483066e-01],
#        [-5.89851781e-02, -3.48579969e-01],
#        [ 7.06713723e-01,  3.24798377e-01],
#        [ 5.70582442e-01, -5.43312674e-01],
#        [ 8.33733574e-01,  1.57527348e-01],
#        [-3.02758499e-01,  1.28318229e-02],
#        [-4.14026666e-01,  7.86578271e-01],
#        [ 2.58287049e-01,  2.41402250e-01],
#        [-7.89143306e-02, -1.73917896e-02]])

# %% [markdown]
# # Build Model

# %%
model = nn.Model()
# Add layers
model.add(nn.Layer_Dense(X_train.shape[1], 3))
model.add(nn.Activation_ReLU())
model.add(nn.Layer_Dense(3, 6))
model.add(nn.Activation_ReLU())
model.add(nn.Layer_Dense(6, 3))
model.add(nn.Activation_Softmax())

# %%
model.set(
loss=nn.Loss_CategoricalCrossentropy(),
optimizer=nn.Optimizer_Adam(decay=1e-3),
accuracy=nn.Accuracy_Categorical()
)

# %%
model.finalize()

# %%
model.train(X_train, y_train, batch_size=128, print_every=100, validation_data=(X_test, y_test))
# Out:
# epoch:1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\KEPALA~1\AppData\Local\Temp/ipykernel_16096/2896800161.py in <module>
# ----> 1 model.train(X_train, y_train, batch_size=128, print_every=100, validation_data=(X_test, y_test))
#
# c:\Users\Kepala Laboratorium\Documents\GitHub\Neural-Networks\NeuralNetworks.py in train(self, X, y, epochs, batch_size, print_every, validation_data)
#     821                 predictions = self.output_layer_activation.predictions(output)
#     822                 accuracy = self.accuracy.calculate(predictions,batch_y)
# --> 823
#     824                 # Perform backward pass
#     825                 self.backward(output,batch_y)
#
# AttributeError: 'Accuracy_Categorical' object has no attribute 'calcualte'

# %% [markdown]
# # Model Evaluate

# %%
model.evaluate(X, y)
# Out:
# validation, acc: 0.410 loss: 1.099

# %% [markdown]
# # Model Prediction

# %%
confidences = model.predict(X_test[:5])
